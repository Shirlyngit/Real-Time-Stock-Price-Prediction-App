# %%
pip install pandas_datareader
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 25.1.1
# [notice] To update, run: C:\Users\Administrator\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import pandas_datareader as data 


plt.style.use('fivethirtyeight')
# %matplotlib inline

# %%
pip install yfinance
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 25.1.1
# [notice] To update, run: C:\Users\Administrator\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
import yfinance as yf
import datetime as dt

stock = "POWERGRID.NS" 
start = dt.datetime(2000, 1, 1)
end = dt.datetime(2025, 4, 30)  

df = yf.download(stock, start, end)
# Out:
# YF.download() has changed argument auto_adjust default to True
# [*********************100%***********************]  1 of 1 completed

# %%
df.head()  #2007  stocks records start
# Out:
# Price             Close         High          Low         Open       Volume
# Ticker     POWERGRID.NS POWERGRID.NS POWERGRID.NS POWERGRID.NS POWERGRID.NS
# Date
# 2007-10-05    32.385582    35.250709    26.768003    28.908800    855215656
# 2007-10-08    30.727671    33.480123    30.534515    33.480123    126671715
# 2007-10-09    32.820183    33.109914    29.085861    30.743770    116725709
# 2007-10-10    33.125999    33.802041    32.836269    33.673270     67931378
# 2007-10-11    36.828140    38.630917    32.836281    38.630917    106320954

# %%
df.tail()  #2025 stocks records end
# Out:
# Price             Close         High          Low         Open       Volume
# Ticker     POWERGRID.NS POWERGRID.NS POWERGRID.NS POWERGRID.NS POWERGRID.NS
# Date
# 2025-04-23   314.950012   316.100006   309.450012   314.149994      8225575
# 2025-04-24   314.399994   315.850006   312.850006   314.899994      8021180
# 2025-04-25   306.500000   315.399994   303.399994   313.000000     11475773
# 2025-04-28   308.549988   310.950012   303.549988   304.200012      7314824
# 2025-04-29   302.950012   310.799988   301.200012   308.549988     14678005

# %%
df.shape   #4328 stock records
# Out:
# (4328, 5)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 4328 entries, 2007-10-05 to 2025-04-29
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   (Close, POWERGRID.NS)   4328 non-null   float64
#  1   (High, POWERGRID.NS)    4328 non-null   float64
#  2   (Low, POWERGRID.NS)     4328 non-null   float64
#  3   (Open, POWERGRID.NS)    4328 non-null   float64
#  4   (Volume, POWERGRID.NS)  4328 non-null   int64
# dtypes: float64(4), int64(1)
# memory usage: 202.9 KB

# %%
df.isnull().sum()
# Out:
# Price   Ticker
# Close   POWERGRID.NS    0
# High    POWERGRID.NS    0
# Low     POWERGRID.NS    0
# Open    POWERGRID.NS    0
# Volume  POWERGRID.NS    0
# dtype: int64

# %%
df.describe()
# Out:
# Price         Close         High          Low         Open        Volume
# Ticker POWERGRID.NS POWERGRID.NS POWERGRID.NS POWERGRID.NS  POWERGRID.NS
# count   4328.000000  4328.000000  4328.000000  4328.000000  4.328000e+03
# mean      85.270484    86.380717    84.172362    85.306497  1.193982e+07
# std       72.236571    73.106340    71.323748    72.218865  2.036373e+07
# min       18.908411    20.212439    16.952369    20.114637  0.000000e+00
# 25%       36.556239    37.104084    36.042919    36.638323  4.876600e+06
# 50%       62.082008    63.274451    61.066543    62.147207  8.495812e+06
# 75%       84.999664    86.096462    84.073371    85.098146  1.377905e+07
# max      356.113861   356.893408   348.074624   354.749603  8.552157e+08

# %%
df = df.reset_index()

# %%
df.head()
# Out:
# Price        Date        Close         High          Low         Open  \
# Ticker            POWERGRID.NS POWERGRID.NS POWERGRID.NS POWERGRID.NS
# 0      2007-10-05    32.385582    35.250709    26.768003    28.908800
# 1      2007-10-08    30.727671    33.480123    30.534515    33.480123
# 2      2007-10-09    32.820183    33.109914    29.085861    30.743770
# 3      2007-10-10    33.125999    33.802041    32.836269    33.673270
# 4      2007-10-11    36.828140    38.630917    32.836281    38.630917
#
# Price        Volume
# Ticker POWERGRID.NS
# 0         855215656
# 1         126671715
# 2         116725709
# 3          67931378
# 4         106320954

# %%
pip install plotly
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 25.1.1
# [notice] To update, run: C:\Users\Administrator\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
pip install nbformat>=4.2.0
# Out:
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 25.1.1
# [notice] To update, run: C:\Users\Administrator\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
df.to_csv("powergrid.csv")
data01 = pd.read_csv("powergrid.csv")
data01.head()
# Out:
#     Price        Date               Close                High  \
# 0  Ticker         NaN        POWERGRID.NS        POWERGRID.NS
# 1       0  2007-10-05  32.385581970214844  35.250708662549606
# 2       1  2007-10-08  30.727670669555664  33.480122790770764
# 3       2  2007-10-09   32.82018280029297   33.10991372744685
# 4       3  2007-10-10  33.125999450683594   33.80204096867718
#
#                   Low                Open        Volume
# 0        POWERGRID.NS        POWERGRID.NS  POWERGRID.NS
# 1   26.76800292891584  28.908800170638344     855215656
# 2  30.534515292099577  33.480122790770764     126671715
# 3  29.085860943707615  30.743769817332836     116725709
# 4   32.83626861907928   33.67327001215155      67931378

# %%
data01.tail()
# Out:
#      Price        Date               Close                High  \
# 4324  4323  2025-04-23  314.95001220703125   316.1000061035156
# 4325  4324  2025-04-24   314.3999938964844   315.8500061035156
# 4326  4325  2025-04-25               306.5   315.3999938964844
# 4327  4326  2025-04-28  308.54998779296875  310.95001220703125
# 4328  4327  2025-04-29  302.95001220703125  310.79998779296875
#
#                      Low                Open    Volume
# 4324  309.45001220703125   314.1499938964844   8225575
# 4325   312.8500061035156   314.8999938964844   8021180
# 4326   303.3999938964844               313.0  11475773
# 4327  303.54998779296875  304.20001220703125   7314824
# 4328  301.20001220703125  308.54998779296875  14678005

# %%
#Candlestick plot - for stock price movements
import plotly.graph_objects as go 

fig = go.Figure(data=[go.Candlestick(x = data01['Date'], open = data01['Open'],
                                     high = data01['High'],
                                     low = data01['Low'],
                                     close = data01['Close'])])
fig.update_layout(xaxis_rangeslider_visible=False)
fig.show()

# %%
df = df.drop('Date', axis = 1)
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_1840\32236560.py:1: PerformanceWarning:
#
# dropping on a non-lexsorted multi-index without a level parameter may impact performance.

# %%
df.head()
# Out:
# Price         Close         High          Low         Open       Volume
# Ticker POWERGRID.NS POWERGRID.NS POWERGRID.NS POWERGRID.NS POWERGRID.NS
# 0         32.385582    35.250709    26.768003    28.908800    855215656
# 1         30.727671    33.480123    30.534515    33.480123    126671715
# 2         32.820183    33.109914    29.085861    30.743770    116725709
# 3         33.125999    33.802041    32.836269    33.673270     67931378
# 4         36.828140    38.630917    32.836281    38.630917    106320954

# %%
plt.figure(figsize=(12,6))
plt.plot(df['Close'], label = f'{stock} Closing Price', linewidth = 2)
plt.title(f'{stock} Closing prices over time')
plt.xlabel('\nDate')
plt.ylabel('Closing Price (USD)\n')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(12,6))
plt.plot(df['Open'], label = f'{stock} Opening Price', linewidth = 2)
plt.title(f'{stock} Opening prices over time')
plt.xlabel('\nDate')
plt.ylabel('Opening Price (USD)\n')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(12,6))
plt.plot(df['High'], label = f'{stock} High Prices', linewidth = 2)
plt.title(f'{stock} High Prices over time')
plt.xlabel('\nDate')
plt.ylabel('High Price (USD)\n')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(12,6))
plt.plot(df['Volume'], label = f'{stock} Volume Price', linewidth = 2)
plt.title(f'{stock} Volume Prices over time')
plt.xlabel('\nDate')
plt.ylabel('Volume Price (USD)\n')
plt.legend()
plt.show()

# %%
# Moving Average
# [10, 20, 30, 40, 50, 60, 70, 80, 90]
# moving average for last 5 days -> null null null null 30.0 40.0 50.0

temp_data = [10, 20, 30, 40, 50, 60, 70, 80, 90]
print(sum(temp_data[2:7])/5)
# Out:
# 50.0

# %%
import pandas as pd
df01 = pd.DataFrame(temp_data)
df01
# Out:
#     0
# 0  10
# 1  20
# 2  30
# 3  40
# 4  50
# 5  60
# 6  70
# 7  80
# 8  90

# %%
df01.rolling(5).mean()
# Out:
#       0
# 0   NaN
# 1   NaN
# 2   NaN
# 3   NaN
# 4  30.0
# 5  40.0
# 6  50.0
# 7  60.0
# 8  70.0

# %%
# Closing Price Moving Average for last 100 days

ma100 = df.Close.rolling(100).mean()

# %%
ma100
# Out:
# Ticker  POWERGRID.NS
# 0                NaN
# 1                NaN
# 2                NaN
# 3                NaN
# 4                NaN
# ...              ...
# 4323      292.531125
# 4324      292.321842
# 4325      292.088911
# 4326      291.918488
# 4327      291.707386
#
# [4328 rows x 1 columns]

# %%
# Closing Price Moving Average for the last 200 days

ma200 = df.Close.rolling(200).mean() 
ma200
# Out:
# Ticker  POWERGRID.NS
# 0                NaN
# 1                NaN
# 2                NaN
# 3                NaN
# 4                NaN
# ...              ...
# 4323      309.228625
# 4324      309.181151
# 4325      309.094901
# 4326      308.997640
# 4327      308.872379
#
# [4328 rows x 1 columns]

# %%
plt.figure(figsize=(12,6))
plt.plot(df['Close'], label = f'{stock} Closing Price (USD)', linewidth = 2)
plt.plot(ma100, label = f'{stock} Moving Average Per 100 days', linewidth = 2)
plt.plot(ma200, label = f'{stock} Moving Average Per 200 days', linewidth = 2)
plt.title('Closing Price Moving Average Trend')
plt.legend()
plt.show()

# %%
# Predicting next 30 days stocks - LSTM

#Exponential Moving Average 
ema100 = df.Close.ewm(span=100, adjust=False).mean()

# %%
ema200 = df['Close'].ewm(span=200, adjust=False).mean()

# %%
df.pct_change
# Out:
# <bound method NDFrame.pct_change of Price         Close         High          Low         Open       Volume
# Ticker POWERGRID.NS POWERGRID.NS POWERGRID.NS POWERGRID.NS POWERGRID.NS
# 0         32.385582    35.250709    26.768003    28.908800    855215656
# 1         30.727671    33.480123    30.534515    33.480123    126671715
# 2         32.820183    33.109914    29.085861    30.743770    116725709
# 3         33.125999    33.802041    32.836269    33.673270     67931378
# 4         36.828140    38.630917    32.836281    38.630917    106320954
# ...             ...          ...          ...          ...          ...
# 4323     314.950012   316.100006   309.450012   314.149994      8225575
# 4324     314.399994   315.850006   312.850006   314.899994      8021180
# 4325     306.500000   315.399994   303.399994   313.000000     11475773
# 4326     308.549988   310.950012   303.549988   304.200012      7314824
# 4327     302.950012   310.799988   301.200012   308.549988     14678005
#
# ...

# %%
plt.figure(figsize=(12,6))
plt.plot(df['Close'], label = f'{stock} Closing Price (USD)', linewidth = 1)
plt.plot(ema100, label = f'{stock} Exp. Moving Average Per 100 days', linewidth = 1)
plt.plot(ema200, label = f'{stock} Exp. Moving Average Per 200 days', linewidth = 1)
plt.legend()
plt.show()

# %%
#Training and Testing

data_training = pd.DataFrame(df['Close'][0:int(len(df) * 0.70)])
data_testing = pd.DataFrame(df['Close'][int(len(df)*0.70): int(len(df))])

# %%
data_training.shape
# Out:
# (3029, 1)

# %%
data_testing.shape
# Out:
# (1299, 1)

# %%
from sklearn.preprocessing import MinMaxScaler 

scaler = MinMaxScaler(feature_range = (0, 1))

# %%
data_training_array = scaler.fit_transform(data_training)

# %%
data_training_array
# Out:
# array([[0.19808608],
#        [0.17371827],
#        [0.2044738 ],
#        ...,
#        [0.94249214],
#        [0.91227641],
#        [0.88840656]])

# %%
x_train = []
y_train = []

for i in range(100, data_training_array.shape[0]):
    x_train.append(data_training_array[i-100:i])
    y_train.append(data_training_array[i, 0])

x_train, y_train = np.array(x_train), np.array(y_train)

# %%
x_train.shape
# Out:
# (2929, 100, 1)

# %%
pip install keras
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 25.1.1
# [notice] To update, run: C:\Users\Administrator\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
pip install tensorflow
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 25.1.1
# [notice] To update, run: C:\Users\Administrator\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
#Model Building 
from keras.layers import Dense, Dropout, LSTM, Input 
from keras.models import Sequential

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dropout, Dense, Input

# Initialize the model
model = Sequential([
    Input(shape=(x_train.shape[1], 1)),  # Explicit input layer

    LSTM(units=50, activation='relu', return_sequences=True),
    Dropout(0.2),

    LSTM(units=60, activation='relu', return_sequences=True),
    Dropout(0.3),

    LSTM(units=80, activation='relu', return_sequences=True),
    Dropout(0.4),

    LSTM(units=120, activation='relu'),
    Dropout(0.5),

    Dense(units=1)  # Output layer
])

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                     │ (None, 100, 50)        │        10,400 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 100, 50)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_1 (LSTM)                   │ (None, 100, 60)        │        26,640 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 100, 60)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_2 (LSTM)                   │ (None, 100, 80)        │        45,120 │
# ...

# %%
model.compile(optimizer = 'adam', loss = 'mean_squared_error')
model.fit(x_train, y_train, epochs = 50)
# Out:
# Epoch 1/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 32s 206ms/step - loss: 0.0768
# Epoch 2/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 20s 204ms/step - loss: 0.0098
# Epoch 3/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 19s 204ms/step - loss: 0.0072
# Epoch 4/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 19s 210ms/step - loss: 0.0066
# Epoch 5/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 20s 201ms/step - loss: 0.0067
# Epoch 6/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 19s 206ms/step - loss: 0.0060
# Epoch 7/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 19s 205ms/step - loss: 0.0059
# Epoch 8/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 19s 202ms/step - loss: 0.0056
# Epoch 9/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 19s 210ms/step - loss: 0.0059
# Epoch 10/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 20s 214ms/step - loss: 0.0046
# Epoch 11/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 20s 212ms/step - loss: 0.0048
# Epoch 12/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 19s 208ms/step - loss: 0.0043
# Epoch 13/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 19s 208ms/step - loss: 0.0040
# Epoch 14/50
# ...

# %%
past_100_days = data_training.tail(100)

# %%
past_100_days.head()
# Out:
# Ticker  POWERGRID.NS
# 2929       82.436516
# 2930       81.018028
# 2931       80.956360
# 2932       81.963699
# 2933       83.669983

# %%
data_testing.head()
# Out:
# Ticker  POWERGRID.NS
# 3029       78.304428
# 3030       79.106178
# 3031       79.928482
# 3032       76.824257
# 3033       77.029846

# %%
final_df = pd.concat([past_100_days, data_testing], ignore_index = True)

# %%
final_df.head()
# Out:
# Ticker  POWERGRID.NS
# 0          82.436516
# 1          81.018028
# 2          80.956360
# 3          81.963699
# 4          83.669983

# %%
input_data = scaler.fit_transform(final_df)

# %%
x_test = []
y_test = []

for i in range(100, input_data.shape[0]):
    x_test.append(input_data[i-100:i])
    y_test.append(input_data[i, 0])

x_test, y_test = np.array(x_test), np.array(y_test)

# %%
x_test.shape
# Out:
# (1299, 100, 1)

# %%
y_predicted = model.predict(x_test)
# Out:
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 5s 88ms/step

# %%
y_predicted.shape
# Out:
# (1299, 1)

# %%
scaler.scale_
# Out:
# array([0.00339369])

# %%
scaler_factor = 1/0.00339719
y_predicted = y_predicted * scaler_factor
y_test = y_test * scaler_factor

# %%
plt.figure(figsize=(12, 6))
plt.plot(y_test, label = 'Original Price', linewidth =1 )
plt.plot(y_predicted, label = 'Predicted Price', linewidth = 1)
plt.legend()
plt.show()

# %%
model.save('stock_dl_model.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
